# %%
import sys
from pathlib import Path

# Añadir la raíz del proyecto al sys.path
project_root = Path().resolve().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

# %%
from idescat import IdesCat

# %%
idescat = IdesCat()
comarques = idescat.get_nodes()['fitxes']['v']['v']
# Out:
# 200

# %%
municipis = []
for comarca in comarques:
	municipis.extend(comarca['v'])

print(municipis[0])
# Out:
# {'scheme': 'mun', 'id': '430017', 'content': 'Aiguamúrcia'}

# %%
import random
node = random.choice(municipis)
node_id = node['id']
node_name = node['content']

print(f"ID: {node_id}")
print(f"Name: {node_name}")
# Out:
# ID: 171931
# Name: Sils

# %%
dades = idescat.get_info(node_id)
# Out:
# 200

# %%
dades
# Out:
# {'fitxes': {'p': 'id=171931',
#   'gg': {'g': [{'tt': {'t': {'ff': {'f': [{'r': '2024',
#           'c': 'Superfície',
#           'u': 'km²',
#           'v': '29.91,995.05,32107.98',
#           'calt': 'Superfície',
#           'id': 'f271',
#           'updated': '2024-12-19T11:00:00+00:00'},
#          {'r': '2013',
#           'c': 'Altitud',
#           'u': 'm',
#           'v': '76,_,_',
#           'calt': 'Altitud',
#           'id': 'f258',
#           'updated': '2014-02-17T11:00:00+00:00'},
#          {'r': '2013',
#           'c': 'Longitud',
#           'u': 'º',
#           'v': '2.744792,_,_',
#           'calt': 'Longitud',
#           'id': 'f328',
#           'updated': '2014-02-17T11:00:00+00:00'},
#          {'r': '2013',
#           'c': 'Latitud',
#           'u': 'º',
#           'v': '41.808700,_,_',
#           'calt': 'Latitud',
#           'id': 'f329',
#           'updated': '2014-02-17T11:00:00+00:00'},
#          {'r': '2013',
#           'c': 'Coordenades UTM x',
#           'u': 'm',
#           'v': '478800,_,_',
#           'calt': 'Coordenades UTM x',
#           'id': 'f259',
#           'updated': '2014-02-17T11:00:00+00:00'},
#          {'r': '2013',
#           'c': 'Coordenades UTM y',
#           'u': 'm',
#           'v': '4628650,_,_',
#           'calt': 'Coordenades UTM y',
#           'id': 'f260',
#           'updated': '2014-02-17T11:00:00+00:00'}]},
#        'c': 'Indicadors geogràfics',
#        'id': 't176',
#        'l': 'https://www.idescat.cat/pub/?id=inddt&n=396&geo=mun:171931'}},
#      'c': 'Territori',
#      'id': 'g173'},
#     {'tt': {'t': [{'ff': {'f': [{'c': 'Superfície',
#            'u': 'km²',
#            'v': '29.91,995.05,32107.98',
#            'calt': 'Superfície',
#            'id': 'f261'},
#           {'c': 'Densitat',
#            'u': 'hab./km²',
#            'v': '224.2,186.2,249.5',
#            'calt': 'Densitat',
#            'id': 'f262'}]},
#         'r': '2024',
#         'c': 'Densitat de població',
#         'calt': 'Densitat',
#         'id': 't192',
#         'l': 'https://www.idescat.cat/pub/?id=inddt&n=396&geo=mun:171931',
#         'updated': '2024-12-19T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Homes',
#            'v': '3435,93381,3943698',
#            'calt': 'Homes',
#            'id': 'f318'},
#           {'c': 'Dones',
#            'v': '3271,91883,4068533',
#            'calt': 'Dones',
#            'id': 'f320'},
#           {'c': 'Total',
#            'v': '6706,185264,8012231',
#            'calt': 'Població',
#            'id': 'f321'}]},
#         'r': '2024',
#         'c': 'Població. Per sexe',
#         's': "Idescat, a partir del Cens de població anual de l'INE.",
#         'calt': 'Sexe',
#         'id': 't195',
#         'l': 'https://www.idescat.cat/pub/?id=censph&n=538&geo=mun:171931',
#         'updated': '2024-12-19T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'De 0 a 14 anys',
#            'v': '1049,26226,1097534',
#            'calt': 'Població de 0 a 14 anys',
#            'id': 'f167'},
#           {'c': 'De 15 a 64 anys',
#            'v': '4524,124292,5349199',
#            'calt': 'Població de 15 a 64 anys',
#            'id': 'f27'},
#           {'c': 'De 65 a 84 anys',
#            'v': '977,29878,1311832',
#            'calt': 'Població de 65 a 84 anys',
#            'id': 'f28'},
#           {'c': 'De 85 anys i més',
#            'v': '156,4868,253666',
#            'calt': 'Població de 85 anys i més',
#            'id': 'f29'},
#           {'c': 'Total',
#            'v': '6706,185264,8012231',
#            'calt': 'Població',
#            'id': 'f171'}]},
#         'r': '2024',
#         'c': "Població. Per grups d'edat",
#         's': "Idescat, a partir del Cens de població anual de l'INE.",
#         'calt': "Grups d'edat",
#         'id': 't25',
#         'l': 'https://www.idescat.cat/pub/?id=censph&n=539&geo=mun:171931',
#         'updated': '2025-02-27T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'De 0 a 14 anys',
#            'v': '556,13427,565197',
#            'calt': 'Homes de 0 a 14 anys',
#            'id': 'f176'},
#           {'c': 'De 15 a 64 anys',
#            'v': '2344,64063,2704320',
#            'calt': 'Homes de 15 a 64 anys',
#            'id': 'f33'},
#           {'c': 'De 65 a 84 anys',
#            'v': '479,14171,589410',
#            'calt': 'Homes de 65 a 84 anys',
#            'id': 'f34'},
#           {'c': 'De 85 anys i més',
#            'v': '56,1720,84771',
#            'calt': 'Homes de 85 anys i més',
#            'id': 'f35'},
#           {'c': 'Total',
#            'v': '3435,93381,3943698',
#            'calt': 'Homes',
#            'id': 'f36'}]},
#         'r': '2024',
#         'c': "Població. Per grups d'edat. Homes",
#         's': "Idescat, a partir del Cens de població anual de l'INE.",
#         'calt': "Grups d'edat. Homes",
#         'id': 't31',
#         'l': 'https://www.idescat.cat/pub/?id=censph&n=539&geo=mun:171931',
#         'updated': '2025-02-27T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'De 0 a 14 anys',
#            'v': '493,12799,532337',
#            'calt': 'Dones de 0 a 14 anys',
#            'id': 'f38'},
#           {'c': 'De 15 a 64 anys',
#            'v': '2180,60229,2644879',
#            'calt': 'Dones de 15 a 64 anys',
#            'id': 'f39'},
#           {'c': 'De 65 a 84 anys',
#            'v': '498,15707,722422',
#            'calt': 'Dones de 65 a 84 anys',
#            'id': 'f40'},
#           {'c': 'De 85 anys i més',
#            'v': '100,3148,168895',
#            'calt': 'Dones de 85 anys i més',
#            'id': 'f41'},
#           {'c': 'Total',
#            'v': '3271,91883,4068533',
#            'calt': 'Dones',
#            'id': 'f42'}]},
#         'r': '2024',
#         'c': "Població. Per grups d'edat. Dones",
#         's': "Idescat, a partir del Cens de població anual de l'INE.",
#         'calt': "Grups d'edat. Dones",
#         'id': 't37',
#         'l': 'https://www.idescat.cat/pub/?id=censph&n=539&geo=mun:171931',
#         'updated': '2025-02-27T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Catalunya',
#            'v': '4820,113050,4981501',
#            'calt': 'Població nascuda a Catalunya',
#            'id': 'f69'},
#           {'c': "Resta d'Espanya",
#            'v': '868,23946,1124048',
#            'calt': "Població nascuda a la resta d'Espanya",
#            'id': 'f72'},
#           {'c': 'Estranger',
#            'v': '1018,48268,1906682',
#            'calt': "Població nascuda a l'estranger",
#            'id': 'f73'},
#           {'c': 'Total',
#            'v': '6706,185264,8012231',
#            'calt': 'Població',
#            'id': 'f74'}]},
#         'r': '2024',
#         'c': 'Població. Per lloc de naixement',
#         's': "Idescat, a partir del Cens de població anual de l'INE.",
#         'calt': 'Lloc de naixement',
#         'id': 't68',
#         'l': 'https://www.idescat.cat/pub/?id=censph&n=293&geo=mun:171931',
#         'updated': '2025-02-27T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Espanyola',
#            'v': '5871,144480,6568039',
#            'calt': 'Població amb nacionalitat espanyola',
#            'id': 'f183'},
#           {'c': 'Estrangera',
#            'v': '835,40784,1444192',
#            'calt': 'Població amb nacionalitat estrangera',
#            'id': 'f184'},
#           {'c': 'Total',
#            'v': '6706,185264,8012231',
#            'calt': 'Població',
#            'id': 'f263'}]},
#         'r': '2024',
#         'c': 'Població. Per nacionalitat',
#         's': "Idescat, a partir del Cens de població anual de l'INE.",
#         'calt': 'Nacionalitat',
#         'id': 't75',
#         'l': 'https://www.idescat.cat/pub/?id=censph&n=479&geo=mun:171931',
#         'updated': '2025-02-27T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Espanyola',
#            'v': '2954,72299,3197752',
#            'calt': 'Homes amb nacionalitat espanyola',
#            'id': 'f178'},
#           {'c': 'Estrangera',
#            'v': '481,21082,745946',
#            'calt': 'Homes amb nacionalitat estrangera',
#            'id': 'f77'},
#           {'c': 'Total',
#            'v': '3435,93381,3943698',
#            'calt': 'Homes',
#            'id': 'f264'}]},
#         'r': '2024',
#         'c': 'Població. Per nacionalitat. Homes',
#         's': "Idescat, a partir del Cens de població anual de l'INE.",
#         'calt': 'Nacionalitat. Homes',
#         'id': 't78',
#         'l': 'https://www.idescat.cat/pub/?id=censph&n=479&geo=mun:171931',
#         'updated': '2025-02-27T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Espanyola',
#            'v': '2917,72181,3370287',
#            'calt': 'Dones amb nacionalitat espanyola',
#            'id': 'f82'},
#           {'c': 'Estrangera',
#            'v': '354,19702,698246',
#            'calt': 'Dones amb nacionalitat estrangera',
#            'id': 'f83'},
#           {'c': 'Total',
#            'v': '3271,91883,4068533',
#            'calt': 'Dones',
#            'id': 'f265'}]},
#         'r': '2024',
#         'c': 'Població. Per nacionalitat. Dones',
#         's': "Idescat, a partir del Cens de població anual de l'INE.",
#         'calt': 'Nacionalitat. Dones',
#         'id': 't81',
#         'l': 'https://www.idescat.cat/pub/?id=censph&n=479&geo=mun:171931',
#         'updated': '2025-02-27T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Homes',
#            'v': '40,3138,197314',
#            'calt': "Homes residents a l'estranger",
#            'id': 'f334'},
#           {'c': 'Dones',
#            'v': '40,2642,189172',
#            'calt': "Dones residents a l'estranger",
#            'id': 'f335'},
#           {'c': 'Total',
#            'v': '80,5780,386486',
#            'calt': "Població resident a l'estranger",
#            'id': 'f336'}]},
#         'r': '2024',
#         'c': "Població resident a l'estranger a 1 de gener. Per sexe",
#         's': "Idescat, a partir del Padró d'espanyols residents a l'estranger de l'INE.",
#         'calt': "Població resident a l'estranger",
#         'id': 't197',
#         'l': 'https://www.idescat.cat/pub/?id=phre&n=3697&geo=mun:171931',
#         'updated': '2024-04-22T10:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Població resident',
#            'v': '6616,182614,7901963',
#            'calt': 'Població resident',
#            'id': 'f341'},
#           {'c': 'Població estacional ETCA',
#            'v': '-47,30986,_',
#            'calt': 'Població estacional ETCA',
#            'id': 'f342'},
#           {'c': 'Total',
#            'v': '6569,213600,_',
#            'calt': 'Població ETCA',
#            'id': 'f343'},
#           {'c': 'Població ETCA / població resident',
#            'u': '%',
#            'v': '99.3,117.0,_',
#            'calt': 'Pob. ETCA / pob. resident',
#            'id': 'f344'}]},
#         'r': '2023 (p)',
#         'c': 'Població ETCA (equivalent a temps complet anual)',
#         's': 'Idescat. Estimacions de població estacional (base 2021).',
#         'calt': 'Població estacional',
#         'id': 't198',
#         'l': 'https://www.idescat.cat/pub/?id=epe&n=17886&geo=mun:171931',
#         'updated': '2024-12-11T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Alumnes residents',
#            'v': '1145,28290,1230655',
#            'calt': 'Alumnes residents (edat escolar)',
#            'id': 'f380'},
#           {'c': 'Alumnes residents que estudien al mateix municipi',
#            'u': '%',
#            'v': '65.9,78.8,81.6',
#            'calt': 'Alumnes residents que estudien al mateix municipi',
#            'id': 'f381'}]},
#         'r': 'Curs 2023/24',
#         'c': "Mobilitat obligada per raó d'estudis no universitaris",
#         's': "Idescat, a partir de les dades de la matrícula del Departament d'Educació.",
#         'calt': "Mobilitat obligada per raó d'estudi",
#         'id': 't211',
#         'l': 'https://www.idescat.cat/pub/?id=emoesc&n=8809&geo=mun:171931',
#         'updated': '2024-10-07T10:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Nens',
#            'v': '23,668,27870',
#            'calt': 'Naixements. Nens',
#            'id': 'f185'},
#           {'c': 'Nenes',
#            'v': '23,584,26347',
#            'calt': 'Naixements. Nenes',
#            'id': 'f186'},
#           {'c': 'Total',
#            'v': '46,1252,54217',
#            'calt': 'Naixements',
#            'id': 'f187'}]},
#         'r': '2023',
#         'c': 'Naixements. Per sexe',
#         's': 'Idescat. Estadística de naixements. Moviment natural de la població.',
#         'calt': 'Naixements',
#         'id': 't164',
#         'l': 'https://www.idescat.cat/pub/?id=naix&n=364&geo=mun:171931',
#         'updated': '2024-07-03T10:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Homes',
#            'v': '30,810,34053',
#            'calt': 'Defuncions. Homes',
#            'id': 'f181'},
#           {'c': 'Dones',
#            'v': '33,710,33609',
#            'calt': 'Defuncions. Dones',
#            'id': 'f182'},
#           {'c': 'Total',
#            'v': '63,1520,67662',
#            'calt': 'Defuncions',
#            'id': 'f188'}]},
#         'r': '2023',
#         'c': 'Defuncions. Per sexe',
#         's': "Idescat a partir de l'INE, Estadística de defuncions. Moviment natural de la població.",
#         'calt': 'Defuncions',
#         'id': 't165',
#         'l': 'https://www.idescat.cat/pub/?id=def&n=365&geo=mun:171931',
#         'updated': '2024-12-02T11:00:00+00:00'},
#        {'ff': {'f': {'c': 'Total',
#           'v': '25,685,27068',
#           'calt': 'Matrimonis',
#           'id': 'f179'}},
#         'r': '2023',
#         'c': 'Matrimonis',
#         's': "Idescat, a partir de l’Estadística de matrimonis i del Moviment natural de la població, de l'INE.",
#         'calt': 'Matrimonis',
#         'id': 't166',
#         'l': 'https://www.idescat.cat/pub/?id=mat&n=317&geo=mun:171931',
#         'updated': '2024-12-04T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Una persona',
#            'v': '513,17511,762624',
#            'calt': 'Llars amb una persona',
#            'id': 'f98'},
#           {'c': 'Dues persones',
#            'v': '648,19509,871499',
#            'calt': 'Llars amb dues persones',
#            'id': 'f99'},
#           {'c': 'Tres persones',
#            'v': '528,14292,622581',
#            'calt': 'Llars amb tres persones',
#            'id': 'f100'},
#           {'c': 'Quatre persones',
#            'v': '459,11391,500357',
#            'calt': 'Llars amb quatre persones',
#            'id': 'f101'},
#           {'c': 'Cinc persones i més',
#            'v': '198,5340,232296',
#            'calt': 'Llars amb cinc persones i més',
#            'id': 'f405'},
#           {'c': 'Total',
#            'v': '2349,68046,2989357',
#            'calt': 'Llars',
#            'id': 'f107'}]},
#         'r': '2021',
#         'c': 'Llars. Per grandària de la llar',
#         's': "Idescat, a partir del Cens de població i habitatges de l'INE.",
#         'calt': 'Grandària de les llars',
#         'id': 't97',
#         'l': 'https://www.idescat.cat/pub/?id=censph&n=8274&geo=mun:171931',
#         'updated': '2023-12-20T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Una persona',
#            'v': '513,17514,762624',
#            'calt': "Llars d'una persona",
#            'id': 'f109'},
#           {'c': 'Dues persones o més sense nucli',
#            'v': '102,3795,159150',
#            'calt': 'Llars de dues per. o més (sense nucli)',
#            'id': 'f110'},
#           {'c': 'Parella sense fills',
#            'v': '447,13428,597161',
#            'calt': 'Llars de parelles sense fills',
#            'id': 'f111'},
#           {'c': 'Parella amb fills',
#            'v': '879,22005,965843',
#            'calt': 'Llars de parelles amb fills',
#            'id': 'f112'},
#           {'c': 'Pare o mare amb fills',
#            'v': '342,9540,430471',
#            'calt': 'Llars monoparentals',
#            'id': 'f113'},
#           {'c': 'Dos nuclis o més',
#            'v': '63,1767,74108',
#            'calt': 'Llars amb dos nuclis o més',
#            'id': 'f114'},
#           {'c': 'Total',
#            'v': '2349,68046,2989357',
#            'calt': 'Llars',
#            'id': 'f115'}]},
#         'r': '2021',
#         'c': 'Llars. Per tipus de nucli',
#         's': "Idescat, a partir del Cens de població i habitatges de l'INE.",
#         'calt': 'Tipologia de llars',
#         'id': 't108',
#         'l': 'https://www.idescat.cat/pub/?id=censph&n=531&geo=mun:171931',
#         'updated': '2023-12-20T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Saldo amb Catalunya',
#            'v': '145,1046,_',
#            'calt': 'Migracions (saldo) amb Catalunya',
#            'id': 'f322'},
#           {'c': 'Saldo amb Espanya',
#            'v': '-9,-214,-5865',
#            'calt': 'Migracions (saldo) amb Espanya',
#            'id': 'f323'},
#           {'c': 'Saldo migratori intern',
#            'v': '136,832,-5865',
#            'calt': 'Saldo migratori intern',
#            'id': 'f324'}]},
#         'r': '2022',
#         'c': 'Migracions internes. Saldos destinació-procedència',
#         's': "Idescat, a partir de l'Estadística de migracions i canvis de residència de l'INE.",
#         'calt': 'Migracions internes',
#         'id': 't196',
#         'l': 'https://www.idescat.cat/pub/?id=mm&n=223&geo=mun:171931',
#         'updated': '2024-03-25T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Immigracions',
#            'v': '109,8283,274438',
#            'calt': 'Immigracions externes',
#            'id': 'f372'},
#           {'c': 'Emigracions',
#            'v': '92,3275,115892',
#            'calt': 'Emigracions externes',
#            'id': 'f373'}]},
#         'r': '2022',
#         'c': 'Migracions externes',
#         's': "Idescat, a partir de l'Estadística de migracions i canvis de residència de l'INE.",
#         'calt': 'Migracions externes',
#         'id': 't208',
#         'l': 'https://www.idescat.cat/pub/?id=mm&n=5489&geo=mun:171931',
#         'updated': '2024-03-25T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Resta de la UE',
#            'v': '16,717,29090',
#            'calt': 'Immigracions de la resta de la UE',
#            'id': 'f314'},
#           {'c': 'Resta del món',
#            'v': '93,7566,245348',
#            'calt': 'Immigracions de la resta del món',
#            'id': 'f316'},
#           {'c': 'Total',
#            'v': '109,8283,274438',
#            'calt': 'Immigracions externes',
#            'id': 'f317'}]},
#         'r': '2022',
#         'c': 'Immigracions externes. Per lloc de procedència',
#         's': "Idescat, a partir de l'Estadística de migracions i canvis de residència de l'INE.",
#         'calt': 'Immigracions externes',
#         'id': 't194',
#         'l': 'https://www.idescat.cat/pub/?id=mm&n=487&geo=mun:171931',
#         'updated': '2024-03-25T11:00:00+00:00'},
#        {'ff': {'f': [{'r': '',
#            'c': 'Taxa bruta de natalitat',
#            'v': '_,_,_',
#            'calt': 'Taxa bruta de natalitat',
#            'id': 'f330',
#            'updated': '2010-06-11T10:00:00+00:00'},
#           {'r': '',
#            'c': 'Taxa bruta de mortalitat',
#            'v': '_,_,_',
#            'calt': 'Taxa bruta de mortalitat',
#            'id': 'f331',
#            'updated': '2010-06-11T10:00:00+00:00'},
#           {'r': '2023',
#            'c': 'Creixement natural',
#            'v': '-2.56,-1.46,-1.69',
#            'calt': 'Creixement natural',
#            'id': 'f54',
#            'updated': '2024-05-15T10:00:00+00:00'},
#           {'r': '2023',
#            'c': 'Creixement migratori',
#            'v': '15.03,15.13,15.29',
#            'calt': 'Creixement migratori',
#            'id': 'f55',
#            'updated': '2024-05-15T10:00:00+00:00'},
#           {'r': '2023',
#            'c': 'Creixement total',
#            'v': '13.53,14.41,13.86',
#            'calt': 'Creixement total de la població',
#            'id': 'f53',
#            'updated': '2024-05-15T10:00:00+00:00'}]},
#         'c': 'Creixement de la població',
#         's': 'Idescat. Indicadors demogràfics.',
#         'u': 'taxa bruta per 1.000 habitants',
#         'calt': 'Creixement de la població',
#         'id': 't52',
#         'l': 'https://www.idescat.cat/pub/?id=inddt&geo=mun:171931'}]},
#      'c': 'Població',
#      'id': 'g168'},
#     {'tt': {'t': [{'ff': {'f': [{'c': "L'entén",
#            'v': '5246,157435,6949344',
#            'calt': 'Població que entén català',
#            'id': 'f91'},
#           {'c': 'El sap parlar',
#            'v': '4216,122721,5345484',
#            'calt': 'Població que sap parlar català',
#            'id': 'f92'},
#           {'c': 'El sap llegir',
#            'v': '4393,129858,5750348',
#            'calt': 'Població que sap llegir català',
#            'id': 'f93'},
#           {'c': 'El sap escriure',
#            'v': '3425,95781,4069219',
#            'calt': 'Població que sap escriure català',
#            'id': 'f94'},
#           {'c': "No l'entén",
#            'v': '217,8951,356728',
#            'calt': 'Població que no entén català',
#            'id': 'f95'},
#           {'c': 'Total',
#            'v': '5463,166386,7306072',
#            'calt': 'Població de 2 anys i més',
#            'id': 'f96'}]},
#         'r': '2011',
#         'c': 'Població de 2 anys i més. Per coneixement del català',
#         's': "Idescat, a partir del Cens de població i habitatges de l'INE.",
#         'calt': 'Coneixement del català',
#         'id': 't90',
#         'l': 'https://www.idescat.cat/pub/?id=censph&n=17&geo=mun:171931',
#         'updated': '2013-11-21T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Públiques',
#            'v': '1,15,459',
#            'calt': 'Biblioteques públiques',
#            'id': 'f270'},
#           {'c': 'Altres',
#            'v': '0,3,391',
#            'calt': 'Altres biblioteques',
#            'id': 'f327'},
#           {'c': 'Total',
#            'v': '1,18,850',
#            'calt': 'Biblioteques',
#            'id': 'f177'}]},
#         'r': '2018',
#         'c': 'Biblioteques',
#         's': 'Idescat. Estadística de biblioteques.',
#         'calt': 'Biblioteques',
#         'id': 't156',
#         'l': 'https://www.idescat.cat/pub/?id=bib&n=327&geo=mun:171931',
#         'updated': '2019-12-10T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Pavellons',
#            'v': '1,37,1032',
#            'calt': 'Pavellons',
#            'id': 'f293'},
#           {'c': 'Pistes poliesportives',
#            'v': '12,232,8414',
#            'calt': 'Pistes poliesportives',
#            'id': 'f294'},
#           {'c': 'Camps poliesportius',
#            'v': '5,87,2280',
#            'calt': 'Camps poliesportius',
#            'id': 'f295'},
#           {'c': 'Sales esportives',
#            'v': '17,225,9360',
#            'calt': 'Sales esportives',
#            'id': 'f296'},
#           {'c': 'Piscines cobertes',
#            'v': '0,52,1107',
#            'calt': 'Piscines cobertes',
#            'id': 'f301'},
#           {'c': "Pistes d'atletisme",
#            'v': '0,9,436',
#            'calt': "Pistes d'atletisme",
#            'id': 'f302'},
#           {'c': 'Altres espais',
#            'v': '24,1135,29479',
#            'calt': 'Altres espais esportius',
#            'id': 'f299'},
#           {'c': 'Total',
#            'v': '59,1777,52108',
#            'calt': 'Espais esportius',
#            'id': 'f300'}]},
#         'r': '2024',
#         'c': 'Espais esportius',
#         's': "Idescat, a partir de les dades del Consell Català de l'Esport.",
#         'calt': 'Espais esportius',
#         'id': 't175',
#         'l': 'https://www.idescat.cat/pub/?id=eesp&n=4332&geo=mun:171931',
#         'updated': '2025-03-03T11:00:00+00:00'}]},
#      'c': 'Cultura · Llengua',
#      'id': 'g172'},
#     {'tt': {'t': {'ff': {'f': [{'c': 'Educació primària o inferior',
#           'v': '14.9,15.4,14.0',
#           'calt': 'Educació primària o inferior',
#           'id': 'f386'},
#          {'c': 'Primera etapa d’educació secundària',
#           'v': '35.4,35.2,27.9',
#           'calt': 'Primera etapa d’educació secundària',
#           'id': 'f387'},
#          {'c': 'Segona etapa d’educació secundària',
#           'v': '24.9,24.7,23.4',
#           'calt': 'Segona etapa d’educació secundària',
#           'id': 'f388'},
#          {'c': 'Educació superior',
#           'v': '24.8,24.7,34.7',
#           'calt': 'Educació superior',
#           'id': 'f389'}]},
#        'r': '2022',
#        'c': 'Població de 15 anys i més. Per nivell de formació assolit',
#        's': "Idescat, a partir del Cens de població i habitatges de l'INE.",
#        'u': '%',
#        'calt': 'Nivell de formació assolit',
#        'id': 't215',
#        'l': 'https://www.idescat.cat/pub/?id=censph&n=16719&geo=mun:171931',
#        'updated': '2024-06-28T10:00:00+00:00'}},
#      'c': 'Educació',
#      'id': 'g214'},
#     {'tt': {'t': [{'ff': {'f': [{'c': 'Electors',
#            'v': '4369,115863,5422553',
#            'calt': 'Electors (Elec. municipals)',
#            'id': 'f266'},
#           {'c': 'Participació',
#            'u': '%',
#            'v': '61.2,63.3,64.8',
#            'calt': 'Participació (Elec. municipals)',
#            'id': 'f149'}]},
#         'r': '2019',
#         'c': 'Eleccions municipals',
#         's': "Departament d'Acció Exterior i Unió Europea.",
#         'calt': 'Eleccions municipals',
#         'id': 't148',
#         'l': 'https://www.idescat.cat/pub/?id=elem&n=391&geo=mun:171931',
#         'updated': '2023-02-02T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Electors',
#            'v': '4405,115050,5624067',
#            'calt': 'Electors (Elec. Parlament Catalunya)',
#            'id': 'f267'},
#           {'c': 'Participació',
#            'u': '%',
#            'v': '49.1,50.7,51.3',
#            'calt': 'Participació (Elec. Parlament Catalunya)',
#            'id': 'f254'}]},
#         'r': '2021',
#         'c': 'Eleccions al Parlament de Catalunya',
#         'calt': 'Eleccions al Parlament de Catalunya',
#         'id': 't189',
#         'l': 'https://www.idescat.cat/pub/?id=elepc&n=389&geo=mun:171931',
#         'updated': '2023-02-15T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Electors',
#            'v': '4351,113446,5615420',
#            'calt': 'Electors (Elec. Congrés)',
#            'id': 'f268'},
#           {'c': 'Participació',
#            'u': '%',
#            'v': '67.7,69.1,69.4',
#            'calt': 'Participació (Elec. Congrés)',
#            'id': 'f255'}]},
#         'r': '2019',
#         'c': 'Eleccions al Congrés dels Diputats',
#         's': "Departament d'Acció Exterior i Unió Europea.",
#         'calt': 'Eleccions al Congrés dels Diputats',
#         'id': 't190',
#         'l': 'https://www.idescat.cat/pub/?id=elecd&n=385&geo=mun:171931',
#         'updated': '2023-02-15T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Electors',
#            'v': '4359,115548,5645470',
#            'calt': 'Electors (Elec. Parlament Europeu)',
#            'id': 'f269'},
#           {'c': 'Participació',
#            'u': '%',
#            'v': '60.6,62.6,60.9',
#            'calt': 'Participació (Elec. Parlament Europeu)',
#            'id': 'f256'}]},
#         'r': '2019',
#         'c': 'Eleccions al Parlament Europeu',
#         's': "Departament d'Acció Exterior i Unió Europea.",
#         'calt': 'Eleccions al Parlament Europeu',
#         'id': 't191',
#         'l': 'https://www.idescat.cat/pub/?id=elepe&n=390&geo=mun:171931',
#         'updated': '2023-02-27T11:00:00+00:00'}]},
#      'c': 'Eleccions',
#      'id': 'g174'},
#     {'tt': {'t': [{'ff': {'f': [{'c': 'Població ocupada',
#            'v': '2969,69406,3333477',
#            'calt': 'Població ocupada',
#            'id': 'f221'},
#           {'c': 'Població desocupada',
#            'v': '295,9588,365357',
#            'calt': 'Població desocupada',
#            'id': 'f222'},
#           {'c': 'Població activa',
#            'v': '3264,78994,3698834',
#            'calt': 'Població activa',
#            'id': 'f223'},
#           {'c': 'Població inactiva',
#            'v': '2059,70082,2855090',
#            'calt': 'Població inactiva',
#            'id': 'f60'},
#           {'c': 'Població de 16 anys i més',
#            'v': '5323,149076,6553924',
#            'calt': 'Població de 16 anys i més',
#            'id': 'f224'}]},
#         'r': '2022',
#         'c': "Població. Per relació amb l'activitat econòmica",
#         's': "Idescat, a partir del Cens de població i habitatges de l'INE.",
#         'calt': "Relació amb l'activitat econòmica",
#         'id': 't56',
#         'l': 'https://www.idescat.cat/pub/?id=censph&n=270&geo=mun:171931',
#         'updated': '2024-06-28T10:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Homes',
#            'v': '1715,40785,1897740',
#            'calt': 'Homes',
#            'id': 'f378'},
#           {'c': 'Dones',
#            'v': '1510,33080,1693490',
#            'calt': 'Dones',
#            'id': 'f379'},
#           {'c': 'Total',
#            'v': '3225,73865,3591230',
#            'calt': "Afiliats a la Seguretat Social segons residència de l'afiliat",
#            'id': 'f377'}]},
#         'r': '02/2025',
#         'c': "Afiliats a la Seguretat Social segons residència de l'afiliat",
#         's': 'Idescat.',
#         'calt': "Afiliats a la Seguretat Social segons residència de l'afiliat",
#         'id': 't210',
#         'l': 'https://www.idescat.cat/pub/?id=afi&n=8604&geo=mun:171931',
#         'updated': '2025-03-12T11:00:00+00:00'},
#        {'ff': {'f': {'c': 'Total',
#           'v': '3330,76870,3778820',
#           'calt': 'Afiliacions Seguretat Social segons residència',
#           'id': 'f363'}},
#         'r': '02/2025',
#         'c': "Afiliacions a la Seguretat Social segons residència de l'afiliat",
#         's': 'Idescat.',
#         'calt': "Afiliacions a la Seguretat Social segons residència de l'afiliat",
#         'id': 't203',
#         'l': 'https://www.idescat.cat/pub/?id=afi&n=8598&geo=mun:171931',
#         'updated': '2025-03-12T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Agricultura',
#            'v': '5,370,10575',
#            'calt': 'Afiliacions agricultura al R. General SS (ubicació comptes cotització)',
#            'id': 'f273'},
#           {'c': 'Indústria',
#            'v': '825,16585,465880',
#            'calt': 'Afiliacions indústria al R. General SS (ubicació comptes cotització)',
#            'id': 'f278'},
#           {'c': 'Construcció',
#            'v': '130,3710,157645',
#            'calt': 'Afiliacions construcció al R. General SS (ubicació comptes cotització)',
#            'id': 'f279'},
#           {'c': 'Serveis',
#            'v': '1090,27645,2474660',
#            'calt': 'Afiliacions serveis al R. General SS (ubicació comptes cotització)',
#            'id': 'f280'},
#           {'c': 'Total',
#            'v': '2045,48310,3108760',
#            'calt': 'Afiliacions al R. General SS (ubicació comptes cotització)',
#            'id': 'f282'}]},
#         'r': '12/2024 (p)',
#         'c': 'Afiliacions al règim general de la S.S. segons ubicació del compte de cotització. Per sectors',
#         's': "Idescat, a partir dels fitxers d'afiliacions i comptes de cotització de la Tresoreria General de la Seguretat Social.",
#         'calt': 'Afiliacions al règim general segons ubicació del compte de cotització. Per sectors',
#         'id': 't183',
#         'l': 'https://www.idescat.cat/pub/?id=afic&n=14983&geo=mun:171931',
#         'updated': '2025-01-16T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Agricultura',
#            'v': '15,485,20540',
#            'calt': "Afiliacions agri. R.E.T.A. (ubicació de l'activitat)",
#            'id': 'f229'},
#           {'c': 'Indústria',
#            'v': '35,855,36015',
#            'calt': "Afiliacions ind. R.E.T.A.. (ubicació comptes de l'activitat)",
#            'id': 'f288'},
#           {'c': 'Construcció',
#            'v': '75,2000,70335',
#            'calt': "Afiliacions const. R.E.T.A. (ubicació de l'activitat)",
#            'id': 'f289'},
#           {'c': 'Serveis',
#            'v': '275,9040,440345',
#            'calt': "Afiliacions serveis R.E.T.A.. (ubicació de l'activitat)",
#            'id': 'f290'},
#           {'c': 'Total',
#            'v': '400,12385,567235',
#            'calt': "Afiliacions R.E.T.A. (ubicació de l'activitat)",
#            'id': 'f291'}]},
#         'r': '12/2024 (p)',
#         'c': "Afiliacions al règim d'autònoms de la S.S. Per sectors",
#         's': "Idescat, a partir dels fitxers d'afiliacions i comptes de cotització de la Tresoreria General de la Seguretat Social.",
#         'calt': "Afiliacions al règim d'autònoms. Per sectors",
#         'id': 't184',
#         'l': 'https://www.idescat.cat/pub/?id=afic&n=14995&geo=mun:171931',
#         'updated': '2025-01-16T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Fins a 9 treballadors',
#            'v': '440,11580,549760',
#            'calt': 'Afiliacions a centres SS fins a 9 treb. (ubicació comptes cotització)',
#            'id': 'f225'},
#           {'c': 'De 10 a 49 treballadors',
#            'v': '585,14200,736230',
#            'calt': 'Afiliacions a centres SS de 10 a 49 treb. (ubicació comptes cotització)',
#            'id': 'f284'},
#           {'c': 'De 50 a 249 treballadors',
#            'v': '610,14075,743495',
#            'calt': 'Afiliacions a centres SS de 50 a 249 treb. (ubicació comptes cotització)',
#            'id': 'f390'},
#           {'c': 'De 250 i més treballadors',
#            'v': '410,8455,1079275',
#            'calt': 'Afiliacions a centres SS de 250 i més treb. (ubicació comptes cotització)',
#            'id': 'f227'},
#           {'c': 'Total',
#            'v': '2045,48310,3108760',
#            'calt': 'Afiliacions al R. General SS (ubicació comptes cotització)',
#            'id': 'f286'}]},
#         'r': '12/2024 (p)',
#         'c': 'Afiliacions al règim general de la S.S. segons ubicació del compte de cotització. Per grandària del compte',
#         's': "Idescat, a partir dels fitxers d'afiliacions i comptes de cotització de la Tresoreria General de la Seguretat Social.",
#         'calt': 'Afiliacions al règim gen. segons ubicació del compte de cotització. Per grandària del compte',
#         'id': 't185',
#         'l': 'https://www.idescat.cat/pub/?id=afic&n=14993&geo=mun:171931',
#         'updated': '2025-01-16T11:00:00+00:00'},
#        {'ff': {'f': {'c': 'Total',
#           'v': '181,5112,245610',
#           'calt': 'Comptes de cotització',
#           'id': 'f239'}},
#         'r': '12/2024 (p)',
#         'c': 'Comptes de cotització',
#         's': "Idescat, a partir dels fitxers d'afiliacions i comptes de cotització de la Tresoreria General de la Seguretat Social.",
#         'calt': 'Comptes de cotització de la Seguretat Social',
#         'id': 't186',
#         'l': 'https://www.idescat.cat/pub/?id=afic&n=14942&geo=mun:171931',
#         'updated': '2025-01-16T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Total',
#            'v': '1291,37001,1758796',
#            'calt': 'Pensions contributives de la S.S.',
#            'id': 'f375',
#            'updated': '2024-06-26T10:00:00+00:00'},
#           {'c': 'Pensió mitjana',
#            'u': 'euros',
#            'v': '1176.28,1125.59,1259.32',
#            'calt': 'Pensió contributiva mitjana',
#            'id': 'f376',
#            'updated': '2024-06-26T10:00:00+00:00'}]},
#         'r': '2023',
#         'c': 'Pensions contributives de la Seguretat Social. Desembre',
#         's': "Idescat, a partir de dades de l'Institut Nacional de la Seguretat Social.",
#         'calt': 'Pensions contributives de la Seguretat Social',
#         'id': 't209',
#         'l': 'https://www.idescat.cat/pub/?id=pens&geo=mun:171931'},
#        {'ff': {'f': [{'c': 'Homes',
#            'v': '585,16210,741000',
#            'calt': 'Homes',
#            'id': 'f382'},
#           {'c': 'Dones',
#            'v': '542,16162,800323',
#            'calt': 'Dones',
#            'id': 'f383'},
#           {'c': 'Total',
#            'v': '1127,32372,1541323',
#            'calt': 'Total',
#            'id': 'f384'}]},
#         'r': '2023',
#         'c': 'Pensionistes de la Seguretat Social. Per sexe. Desembre',
#         's': "Idescat, a partir de dades de l'Institut Nacional de la Seguretat Social.",
#         'calt': 'Pensionistes de la Seguretat Social',
#         'id': 't212',
#         'l': 'https://www.idescat.cat/pub/?id=pens&n=10756&geo=mun:171931',
#         'updated': '2024-06-26T10:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Agricultura',
#            'v': '3.0,128.8,5273.2',
#            'calt': 'Atur registrat. Agricultura',
#            'id': 'f243'},
#           {'c': 'Indústria',
#            'v': '43.4,949.6,35466.6',
#            'calt': 'Atur registrat. Indústria',
#            'id': 'f303'},
#           {'c': 'Construcció',
#            'v': '31.2,633.2,25611.7',
#            'calt': 'Atur registrat. Construcció',
#            'id': 'f304'},
#           {'c': 'Serveis',
#            'v': '200.8,5322.7,243751.4',
#            'calt': 'Atur registrat. Serveis',
#            'id': 'f305'},
#           {'c': 'Sense ocupació anterior',
#            'v': '17.3,526.3,25595.5',
#            'calt': 'Atur registrat (sense ocupació anterior)',
#            'id': 'f307'},
#           {'c': 'Total',
#            'v': '295.8,7560.6,335698.3',
#            'calt': 'Atur registrat',
#            'id': 'f308'}]},
#         'r': '2024',
#         'c': 'Atur registrat. Per sectors',
#         's': "Departament d'Empresa i Treball.",
#         'u': 'mitjanes anuals',
#         'calt': 'Atur registrat per sectors',
#         'id': 't188',
#         'l': 'https://www.idescat.cat/pub/?id=atureg&n=4302&geo=mun:171931',
#         'updated': '2025-01-29T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Homes',
#            'v': '133.2,3166.9,142232.5',
#            'calt': 'Atur registrat. Homes',
#            'id': 'f240'},
#           {'c': 'Dones',
#            'v': '162.7,4393.7,193465.8',
#            'calt': 'Atur registrat. Dones',
#            'id': 'f241'},
#           {'c': 'Total',
#            'v': '295.8,7560.6,335698.3',
#            'calt': 'Atur registrat',
#            'id': 'f242'}]},
#         'r': '2024',
#         'c': 'Atur registrat. Per sexe',
#         's': "Departament d'Empresa i Treball.",
#         'u': 'mitjanes anuals',
#         'calt': 'Atur registrat per sexe',
#         'id': 't187',
#         'l': 'https://www.idescat.cat/pub/?id=atureg&n=4299&geo=mun:171931',
#         'updated': '2025-01-29T11:00:00+00:00'}]},
#      'c': 'Treball',
#      'id': 'g169'},
#     {'tt': {'t': [{'ff': {'f': [{'c': 'Principals',
#            'v': '2349,68045,2989357',
#            'calt': 'Habitatges familiars principals',
#            'id': 'f250'},
#           {'c': 'No principals',
#            'v': '750,36915,925770',
#            'calt': 'Habitatges familiars no principals',
#            'id': 'f398'},
#           {'c': 'Total',
#            'v': '3099,104960,3915127',
#            'calt': 'Habitatges familiars',
#            'id': 'f122'},
#           {'c': 'Principals (%)',
#            'v': '75.8,64.8,76.4',
#            'calt': 'Habitatges familiars principals (%)',
#            'id': 'f399'}]},
#         'r': '2021',
#         'c': 'Habitatges familiars. Per tipus',
#         's': "Idescat, a partir del Cens de població i habitatges de l'INE.",
#         'calt': "Tipus d'habitatges",
#         'id': 't116',
#         'l': 'https://www.idescat.cat/pub/?id=censph&n=16991&geo=mun:171931',
#         'updated': '2023-10-30T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'De propietat',
#            'v': '1716,46497,2066591',
#            'calt': 'Habitatges familiars principals de propietat',
#            'id': 'f126'},
#           {'c': 'De lloguer',
#            'v': '441,15312,692285',
#            'calt': 'Habitatges familiars principals de lloguer',
#            'id': 'f128'},
#           {'c': 'Altra forma',
#            'v': '192,6237,230481',
#            'calt': 'Habitatges familiars principlas cedits, altres formes',
#            'id': 'f130'},
#           {'c': 'Total',
#            'v': '2349,68046,2989357',
#            'calt': 'Habitatges familiars principals',
#            'id': 'f131'},
#           {'c': 'De lloguer (%)',
#            'v': '18.8,22.5,23.2',
#            'calt': 'Habitatges familiars de lloguer (%)',
#            'id': 'f401'}]},
#         'r': '2021',
#         'c': 'Habitatges familiars principals. Per règim de tinença',
#         's': "Idescat, a partir del Cens de població i habitatges de l'INE.",
#         'calt': 'Règim de tinença dels habitatges',
#         'id': 't124',
#         'l': 'https://www.idescat.cat/pub/?id=censph&n=310&geo=mun:171931',
#         'updated': '2023-10-30T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Fins a 45 m²',
#            'v': '84,6336,270604',
#            'calt': 'Habitatges familiars principals fins a 45 m²',
#            'id': 'f402'},
#           {'c': 'De 46 a 60 m²',
#            'v': '327,10788,657547',
#            'calt': 'Habitatges familiars principals de 46 a 60 m²',
#            'id': 'f403'},
#           {'c': 'De 61 a 90 m²',
#            'v': '828,25572,1181950',
#            'calt': 'Habitatges familiars principals de 61 a 90 m²',
#            'id': 'f190'},
#           {'c': 'De 91 a 120 m²',
#            'v': '546,11982,443055',
#            'calt': 'Habitatges familiars principals de 91 a 120 m²',
#            'id': 'f191'},
#           {'c': 'Més de 120 m²',
#            'v': '540,12534,403659',
#            'calt': 'Habitatges familiars principals de més de 120 m²',
#            'id': 'f192'},
#           {'c': 'No hi consta',
#            'v': '30,831,32542',
#            'calt': 'No hi consta',
#            'id': 'f404'},
#           {'c': 'Total',
#            'v': '2349,68046,2989357',
#            'calt': 'Habitatges familiars principals',
#            'id': 'f193'}]},
#         'r': '2021',
#         'c': 'Habitatges familiars principals. Per superfície útil',
#         's': "Idescat, a partir del Cens de població i habitatges de l'INE.",
#         'calt': 'Superfície útil dels habitatges',
#         'id': 't177',
#         'l': 'https://www.idescat.cat/pub/?id=censph&n=311&geo=mun:171931',
#         'updated': '2023-10-30T11:00:00+00:00'},
#        {'ff': {'f': {'c': 'Índex socioeconòmic territorial',
#           'v': '95.7,88.5,100.0',
#           'calt': 'Índex socioeconòmic territorial',
#           'id': 'f385'}},
#         'r': '2021',
#         'c': 'Índex socioeconòmic territorial (IST). Índex Catalunya=100',
#         's': 'Idescat. Índex socioeconòmic territorial.',
#         'u': 'índex Catalunya=100',
#         'calt': 'IST',
#         'id': 't213',
#         'l': 'https://www.idescat.cat/pub/?id=ist&n=14034&geo=mun:171931',
#         'updated': '2024-06-27T10:00:00+00:00'}]},
#      'c': 'Qualitat de vida',
#      'id': 'g171'},
#     {'tt': {'t': [{'ff': {'f': [{'c': 'PIB',
#            'u': 'milions €',
#            'v': '204.3,5221.5,269505.0',
#            'calt': 'PIB',
#            'id': 'f2'},
#           {'c': 'PIB per habitant',
#            'u': '€',
#            'v': '31254,29046,34411',
#            'calt': 'PIB per habitant',
#            'id': 'f3'},
#           {'c': 'PIB per habitant',
#            'u': 'índex Catalunya=100',
#            'v': '90.8,84.4,100.0',
#            'calt': 'PIB per habitant  (Catalunya=100)',
#            'id': 'f4'}]},
#         'r': '2022 (p)',
#         'c': 'Producte interior brut (Revisió estadística 2019)',
#         's': 'Idescat.',
#         'calt': 'PIB',
#         'id': 't1',
#         'l': 'https://www.idescat.cat/pub/?geo=mun:171931&id=pibc&n=13830#Plegable=geo',
#         'updated': '2023-12-22T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Agricultura',
#            'v': '_,78.4,1980.4',
#            'calt': 'VAB agricultura',
#            'id': 'f194'},
#           {'c': 'Indústria',
#            'v': '_,1307.9,47158.8',
#            'calt': 'VAB indústria',
#            'id': 'f195'},
#           {'c': 'Construcció',
#            'v': '_,258.3,11464.6',
#            'calt': 'VAB construcció',
#            'id': 'f196'},
#           {'c': 'Serveis',
#            'v': '_,3159.6,187359.2',
#            'calt': 'VAB serveis',
#            'id': 'f197'},
#           {'c': 'Total',
#            'v': '_,4804.2,247962.9',
#            'calt': 'VAB',
#            'id': 'f251'}]},
#         'r': '2022 (p)',
#         'c': 'Valor afegit brut (Revisió estadística 2019). Per sectors',
#         's': 'Idescat.',
#         'u': 'milions €',
#         'calt': 'VAB',
#         'id': 't178',
#         'l': 'https://www.idescat.cat/pub/?id=pibc&n=13831&geo=mun:171931',
#         'updated': '2024-12-20T11:00:00+00:00'},
#        {'ff': {'f': [{'c': 'RFDB',
#            'u': 'milers €',
#            'v': '104545,2661839,142363357',
#            'calt': 'RFDB',
#            'id': 'f6'},
#           {'c': 'RFDB per habitant',
#            'u': 'euros',
#            'v': '16305,15112,18356',
#            'calt': 'RFDB per habitant',
#            'id': 'f7'},
#           {'c': 'RFDB per habitant',
#            'u': 'índex Catalunya=100',
#            'v': '88.8,82.3,100.0',
#            'calt': 'RFDB per habitant (Catalunya=100)',
#            'id': 'f8'}]},
#         'r': '2021 (p)',
#         'c': 'Renda familiar disponible bruta. Revisió estadística 2019',
#         's': 'Idescat.',
#         'calt': 'Renda familiar disponible',
#         'id': 't5',
#         'l': 'https://www.idescat.cat/pub/?id=rfdbc&n=13301&geo=mun:171931',
#         'updated': '2024-04-26T10:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Nombre de rebuts',
#            'v': '4577,164020,5970136',
#            'calt': 'IBI. Rebuts',
#            'id': 'f198'},
#           {'c': 'Base imposable per rebut',
#            'u': 'euros',
#            'v': '39825,54214,70177',
#            'calt': 'IBI. Base imposable per rebut',
#            'id': 'f199'},
#           {'c': 'Quota íntegra per rebut',
#            'u': 'euros',
#            'v': '407,437,505',
#            'calt': 'IBI. Quota íntegra per rebut',
#            'id': 'f200'}]},
#         'r': '2023',
#         'c': 'Impost de béns immobles urbans (IBI)',
#         's': 'Idescat, a partir de les dades de la Dirección General del Catastro.',
#         'calt': 'Impost de béns immobles urbans',
#         'id': 't179',
#         'l': 'https://www.idescat.cat/pub/?id=ibi&n=173&geo=mun:171931',
#         'updated': '2024-06-28T10:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Base imposable general per declarant',
#            'v': '23095,22257,27269',
#            'calt': 'IRPF. Base imposable per declarant',
#            'id': 'f10'},
#           {'c': "Quota resultant de l'autoliquidació per declarant",
#            'v': '5491,5677,7975',
#            'calt': 'IRPF. Quota resultant autoliquidació  per declarant',
#            'id': 'f11'}]},
#         'r': '2022',
#         'c': 'Impost sobre la renda de les persones físiques (IRPF)',
#         's': "Idescat, a partir de les dades de l'Agència Estatal d'Administració Tributària.",
#         'u': 'euros',
#         'calt': 'Impost sobre la renda de les persones físiques',
#         'id': 't9',
#         'l': 'https://www.idescat.cat/pub/?id=irpf&n=4070&geo=mun:171931',
#         'updated': '2024-10-30T11:00:00+00:00'}]},
#      'c': 'Macromagnituds · Finances públiques',
#      'id': 'g163'},
#     {'tt': {'t': [{'ff': {'f': [{'c': 'Terres llaurades',
#            'v': '845,10189,800833',
#            'calt': 'Superfície de terres llaurades',
#            'id': 'f133'},
#           {'c': 'Pastures permanents',
#            'v': '0,930,291383',
#            'calt': 'Superfície de pastures permanents',
#            'id': 'f134'},
#           {'c': 'Total',
#            'v': '845,11118,1092215',
#            'calt': 'Superfície agrícola utilitzada',
#            'id': 'f345'}]},
#         'r': '2020',
#         'c': 'Superfície agrícola utilitzada (SAU)',
#         's': "Idescat, a partir de les dades del Cens agrari de l'INE.",
#         'u': 'hectàrees',
#         'calt': 'Superfície agrícola utilitzada',
#         'id': 't132',
#         'l': 'https://www.idescat.cat/pub/?id=censag&n=16059&geo=mun:171931',
#         'updated': '2022-10-27T10:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Cereals per a gra',
#            'v': '520,5014,360408',
#            'calt': 'Conreus de cereals per a gra',
#            'id': 'f391',
#            'updated': '2022-10-27T10:00:00+00:00'},
#           {'c': 'Conreus collits en verd',
#            'v': '174,2218,79907',
#            'calt': 'Conreus collits en verd',
#            'id': 'f392',
#            'updated': '2022-10-27T10:00:00+00:00'},
#           {'c': 'Altres conreus herbacis',
#            'v': '102,1585,48347',
#            'calt': 'Altres conreus herbacis',
#            'id': 'f393',
#            'updated': '2022-10-27T10:00:00+00:00'},
#           {'c': 'Guarets',
#            'v': '46,429,38416',
#            'calt': 'Guarets',
#            'id': 'f346',
#            'updated': '2022-10-27T10:00:00+00:00'},
#           {'c': 'Fruiters a l’aire lliure',
#            'v': '0,690,106030',
#            'calt': 'Conreus de fruiters a l’aire lliure',
#            'id': 'f347',
#            'updated': '2022-10-27T10:00:00+00:00'},
#           {'c': 'Olivera',
#            'v': '0,55,100123',
#            'calt': "Conreus d'olivera",
#            'id': 'f348',
#            'updated': '2022-10-27T10:00:00+00:00'},
#           {'c': 'Vinya',
#            'v': '0,24,59533',
#            'calt': 'Conreus de vinya',
#            'id': 'f349',
#            'updated': '2022-10-27T10:00:00+00:00'},
#           {'c': 'Altres conreus llenyosos',
#            'v': '1,129,7111',
#            'calt': 'Altres conreus llenyosos',
#            'id': 'f350',
#            'updated': '2022-10-27T10:00:00+00:00'},
#           {'c': 'Conreus en hivernacle',
#            'v': '0,42,752',
#            'calt': 'Conreus en hivernacle',
#            'id': 'f394',
#            'updated': '2022-10-27T10:00:00+00:00'},
#           {'c': 'Horts per a consum propi',
#            'v': '0,3,206',
#            'calt': 'Horts per a consum propi',
#            'id': 'f395',
#            'updated': '2022-10-27T10:00:00+00:00'},
#           {'c': 'Total',
#            'v': '845,10189,800833',
#            'calt': 'Terres llaurades',
#            'id': 'f351',
#            'updated': '2022-10-27T10:00:00+00:00'}]},
#         'r': '2020',
#         'c': 'Terres llaurades. Per tipus de conreu',
#         's': "Idescat, a partir de les dades del Cens agrari de l'INE.",
#         'u': 'hectàrees',
#         'calt': 'Terres llaurades',
#         'id': 't199',
#         'l': 'https://www.idescat.cat/pub/?id=censag&n=16063&geo=mun:171931'},
#        {'ff': {'f': [{'c': 'Explotacions amb SAU',
#            'v': '30,511,53903',
#            'calt': 'Explotacions amb SAU',
#            'id': 'f396',
#            'updated': '2022-10-27T10:00:00+00:00'},
#           {'c': 'Explotacions amb ramaderia',
#            'v': '11,186,10890',
#            'calt': 'Explotacions amb ramaderia',
#            'id': 'f397',
#            'updated': '2022-10-27T10:00:00+00:00'}]},
#         'r': '2020',
#         'c': 'Explotacions agràries',
#         's': "Idescat, a partir de les dades del Cens agrari de l'INE.",
#         'calt': 'Explotacions agràries',
#         'id': 't216',
#         'l': 'https://www.idescat.cat/pub/?id=censag&n=16059&geo=mun:171931'},
#        {'ff': {'f': [{'c': 'Bovins',
#            'v': '475,14622,676097',
#            'calt': 'Caps de bovins',
#            'id': 'f141'},
#           {'c': 'Ovins',
#            'v': '_,9674,488771',
#            'calt': "Caps d'ovins",
#            'id': 'f142'},
#           {'c': 'Cabrum',
#            'v': '_,367,69820',
#            'calt': 'Caps de cabrum',
#            'id': 'f252'},
#           {'c': 'Porcins',
#            'v': '51,81658,8192796',
#            'calt': 'Caps de porcins',
#            'id': 'f144'},
#           {'c': 'Aviram',
#            'v': '_,269297,42544012',
#            'calt': "Caps d'aviram",
#            'id': 'f145'},
#           {'c': 'Conilles mares',
#            'v': '_,985,138400',
#            'calt': 'Caps de conilles mares',
#            'id': 'f146'},
#           {'c': 'Equins',
#            'v': '0,160,13380',
#            'calt': "Caps d'equins",
#            'id': 'f147'}]},
#         'r': '2020',
#         'c': 'Caps de bestiar. Per espècies',
#         's': "Idescat, a partir de les dades del Cens agrari de l'INE.",
#         'calt': 'Caps de bestiar',
#         'id': 't140',
#         'l': 'https://www.idescat.cat/pub/?id=censag&n=16101&geo=mun:171931',
#         'updated': '2022-10-27T10:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Habitatges iniciats de protecció oficial',
#            'v': '0,0,3491',
#            'calt': 'Habitatges iniciats de protecció oficial',
#            'id': 'f13'},
#           {'c': 'Habitatges iniciats',
#            'v': '24,256,14418',
#            'calt': 'Habitatges iniciats',
#            'id': 'f14'}]},
#         'r': '2023',
#         'c': "Construcció d'habitatges",
#         's': 'Departament de Territori.',
#         'calt': "Construcció d'habitatges",
#         'id': 't12',
#         'l': 'https://www.idescat.cat/pub/?id=habit&n=86&geo=mun:171931',
#         'updated': '2024-06-10T10:00:00+00:00'},
#        {'ff': {'f': [{'r': '2023',
#            'c': 'Hotels',
#            'v': '1,250,3146',
#            'calt': 'Hotels',
#            'id': 'f215',
#            'updated': '2024-12-23T11:00:00+00:00'},
#           {'r': '2023',
#            'c': "Places d'hotels",
#            'v': '46,43703,321648',
#            'calt': "Places d'hotels",
#            'id': 'f216',
#            'updated': '2024-12-23T11:00:00+00:00'},
#           {'r': '2022',
#            'c': 'Càmpings',
#            'v': '0,27,353',
#            'calt': 'Càmpings',
#            'id': 'f217',
#            'updated': '2023-07-25T10:00:00+00:00'},
#           {'r': '2022',
#            'c': 'Places de càmpings',
#            'v': '0,22905,270342',
#            'calt': 'Places de càmpings',
#            'id': 'f218',
#            'updated': '2023-07-25T10:00:00+00:00'},
#           {'r': '2023',
#            'c': 'Turisme rural',
#            'v': '2,72,2646',
#            'calt': 'Turisme rural',
#            'id': 'f219',
#            'updated': '2024-12-23T11:00:00+00:00'},
#           {'r': '2023',
#            'c': 'Places de turisme rural',
#            'v': '9,706,21576',
#            'calt': 'Places de turisme rural',
#            'id': 'f220',
#            'updated': '2024-12-23T11:00:00+00:00'}]},
#         'c': 'Allotjaments turístics',
#         's': "Idescat, a partir de les dades del Departament d'Empresa i Treball.",
#         'calt': 'Allotjaments turístics',
#         'id': 't182',
#         'l': 'https://www.idescat.cat/pub/?id=turall&geo=mun:171931'},
#        {'ff': {'f': [{'c': 'Turismes',
#            'v': '3752,94056,3502644',
#            'calt': 'Turismes',
#            'id': 'f19'},
#           {'c': 'Motocicletes',
#            'v': '659,28100,947895',
#            'calt': 'Motocicletes',
#            'id': 'f325'},
#           {'c': 'Vehicles industrials',
#            'v': '866,23045,759536',
#            'calt': 'Vehicles industrials',
#            'id': 'f272'},
#           {'c': 'Altres',
#            'v': '209,5186,188179',
#            'calt': 'Altres vehicles',
#            'id': 'f326'},
#           {'c': 'Total',
#            'v': '5486,150387,5398254',
#            'calt': 'Parc de vehicles',
#            'id': 'f163'}]},
#         'r': '2023',
#         'c': 'Parc de vehicles',
#         's': 'Idescat, a partir de les dades de la DGT.',
#         'calt': 'Parc de vehicles',
#         'id': 't18',
#         'l': 'https://www.idescat.cat/pub/?id=parcc&n=291&geo=mun:171931',
#         'updated': '2024-10-07T10:00:00+00:00'}]},
#      'c': 'Sectors econòmics',
#      'id': 'g170'},
#     {'tt': {'t': [{'ff': {'f': [{'c': 'Generació per càpita',
#            'u': 'kg/hab./dia',
#            'v': '1.23,1.68,1.42',
#            'calt': 'Residus municipals per càpita',
#            'id': 'f366'},
#           {'c': 'Recollida selectiva',
#            'u': '%',
#            'v': '76.8,46.8,46.7',
#            'calt': 'Recollida selectiva de residus municipals',
#            'id': 'f368'}]},
#         'r': '2021',
#         'c': 'Residus municipals',
#         's': 'Agència de Residus de Catalunya.',
#         'calt': 'Residus municipals',
#         'id': 't204',
#         'l': 'https://www.idescat.cat/pub/?id=resmc&n=6997&geo=mun:171931',
#         'updated': '2023-04-19T10:00:00+00:00'},
#        {'ff': {'f': [{'c': 'Establiments amb declaració anual de residus',
#            'v': '17,376,15622',
#            'calt': 'Establiments amb declaració de residus ind.',
#            'id': 'f371'},
#           {'c': 'Generació de residus',
#            'u': 'tones',
#            'v': '3118.87,116163.87,3823878.74',
#            'calt': 'Generació de residus',
#            'id': 'f369'}]},
#         'r': '2021',
#         'c': 'Residus industrials',
#         's': 'Agència de Residus de Catalunya.',
#         'calt': 'Residus industrials',
#         'id': 't207',
#         'l': 'https://www.idescat.cat/pub/?id=resic&n=7083&geo=mun:171931',
#         'updated': '2023-05-11T10:00:00+00:00'}]},
#      'c': 'Medi ambient',
#      'id': 'g205'}]},
#   'lang': 'ca',
#   'version': '1.00',
#   'cols': {'col': [{'scheme': 'mun', 'id': '171931', 'content': 'Sils'},
#     {'scheme': 'com', 'id': '34', 'content': 'Selva'},
#     {'scheme': 'ca', 'id': '09', 'content': 'Catalunya'}]},
#   'o': 'dades'}}
